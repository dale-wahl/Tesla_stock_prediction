# %%
from bs4 import BeautifulSoup
import time as t
import pandas as pd
from selenium import webdriver

# %%
# MAC
driver = webdriver.Chrome(executable_path="/Users/dale/Downloads/chromedriver")

# %%
driver.get('https://www.techmeme.com')

# %%
driver.find_element_by_class_name('sbti').send_keys('title:"Tesla"')

# %%
driver.find_element_by_xpath('//input[@type="submit"]').click()

# %%
page = driver.page_source

# %%
for entry in BeautifulSoup(page, 'lxml').find('div', {'class':'items'}):
    print(entry,'\n\n')
# Out:
#
#
#
# <div class="item" onmouseout="shareOff('s1');" onmouseover="shareOn('s1');">
# <table class="shrtbl"><tbody><tr>
# <td><cite>Jordan Novet / <a href="http://www.cnbc.com/" target="_self">CNBC</a>:</cite></td>
# ...
